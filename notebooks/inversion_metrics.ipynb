# %%
## CONFIG
classid = 812

# %%
# !rm -rf /kaggle/working

# %%
# !git clone https://github.com/ml-repro-team-2/re-rosetta.git
# !git checkout aakash
# Out:
# Cloning into 're-rosetta'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 193 (delta 39), reused 180 (delta 26), pack-reused 0
# Receiving objects: 100% (193/193), 38.35 MiB | 7.00 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd /kaggle/working/re-rosetta/
# Out:
# /kaggle/working/re-rosetta

# %%
# !rm -rf /kaggle/working/re-rosetta/matches

# %%
# !cp /kaggle/input/class-949/matches /kaggle/working/re-rosetta -r

# %%
# !ls /kaggle/working/re-rosetta/matches/styleganxl/clip
# Out:
# 812

# %%
#@title Requirements
# !pip install -r requirements.txt
# !pip install transformers
# !pip install openai-clip
# !pip install einops
# !pip install pytorch_pretrained_biggan
# !pip install Ninja
# !pip install timm==0.4.12
# !pip install dill
# Out:
# Collecting clip@ git+https://github.com/openai/CLIP.git@b46f5ac7587d2e1862f8b7b1573179d80dcdd620 (from -r requirements.txt (line 33))
#   Cloning https://github.com/openai/CLIP.git (to revision b46f5ac7587d2e1862f8b7b1573179d80dcdd620) to /tmp/pip-install-44sf2guk/clip_5f5d4e1ae5fc46c1b7f57762e91a5be7
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-44sf2guk/clip_5f5d4e1ae5fc46c1b7f57762e91a5be7
#   Running command git rev-parse -q --verify 'sha^b46f5ac7587d2e1862f8b7b1573179d80dcdd620'
#   Running command git fetch -q https://github.com/openai/CLIP.git b46f5ac7587d2e1862f8b7b1573179d80dcdd620
#   Running command git checkout -q b46f5ac7587d2e1862f8b7b1573179d80dcdd620
#   Resolved https://github.com/openai/CLIP.git to commit b46f5ac7587d2e1862f8b7b1573179d80dcdd620
#   Preparing metadata (setup.py) ... done
# Collecting einops@ git+https://github.com/arogozhnikov/einops.git@d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f (from -r requirements.txt (line 45))
#   Cloning https://github.com/arogozhnikov/einops.git (to revision d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f) to /tmp/pip-install-44sf2guk/einops_fd96de8c79284869aedfdeb7848adad3
#   Running command git clone --filter=blob:none --quiet https://github.com/arogozhnikov/einops.git /tmp/pip-install-44sf2guk/einops_fd96de8c79284869aedfdeb7848adad3
#   Running command git rev-parse -q --verify 'sha^d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f'
#   Running command git fetch -q https://github.com/arogozhnikov/einops.git d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f
#   Running command git checkout -q d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f
#   Resolved https://github.com/arogozhnikov/einops.git to commit d6f7910dc80c8413b7bb400f6f6ad24e3c5f5b0f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytorch3d@ git+https://github.com/facebookresearch/pytorch3d.git@3145dd4d16edaceb394838364b8e87a440f83c10 (from -r requirements.txt (line 171))
#   Cloning https://github.com/facebookresearch/pytorch3d.git (to revision 3145dd4d16edaceb394838364b8e87a440f83c10) to /tmp/pip-install-44sf2guk/pytorch3d_79f55e7a8d03408eb6bbb91f95f7871a
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorch3d.git /tmp/pip-install-44sf2guk/pytorch3d_79f55e7a8d03408eb6bbb91f95f7871a
#   Running command git rev-parse -q --verify 'sha^3145dd4d16edaceb394838364b8e87a440f83c10'
#   Running command git fetch -q https://github.com/facebookresearch/pytorch3d.git 3145dd4d16edaceb394838364b8e87a440f83c10
#   Running command git checkout -q 3145dd4d16edaceb394838364b8e87a440f83c10
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit 3145dd4d16edaceb394838364b8e87a440f83c10
#   Preparing metadata (setup.py) ... done
# Collecting absl-py==1.1.0 (from -r requirements.txt (line 1))
#   Downloading absl_py-1.1.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 4.3 MB/s eta 0:00:00
# Collecting addict==2.4.0 (from -r requirements.txt (line 2))
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting aiofiles==22.1.0 (from -r requirements.txt (line 3))
#   Downloading aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Collecting aiohttp==3.8.1 (from -r requirements.txt (line 4))
#   Downloading aiohttp-3.8.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.9 MB/s eta 0:00:0000:01
# Collecting aiosignal==1.2.0 (from -r requirements.txt (line 5))
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting aiosqlite==0.18.0 (from -r requirements.txt (line 6))
#   Downloading aiosqlite-0.18.0-py3-none-any.whl (15 kB)
# Collecting albumentations==0.4.3 (from -r requirements.txt (line 7))
#   Downloading albumentations-0.4.3.tar.gz (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 75.2 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# Collecting altair==4.2.0 (from -r requirements.txt (line 8))
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 53.4 MB/s eta 0:00:00
# Collecting anyio==3.6.2 (from -r requirements.txt (line 9))
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi==21.3.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.2.3)
# Requirement already satisfied: astunparse==1.6.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.6.3)
# Collecting async-timeout==4.0.2 (from -r requirements.txt (line 15))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting attrs==21.4.0 (from -r requirements.txt (line 16))
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.7 MB/s eta 0:00:00
# Collecting Babel==2.10.3 (from -r requirements.txt (line 17))
#   Downloading Babel-2.10.3-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 86.3 MB/s eta 0:00:00:00:0100:01
# Collecting backports.zoneinfo==0.2.1 (from -r requirements.txt (line 19))
#   Downloading backports.zoneinfo-0.2.1.tar.gz (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting basicsr==1.3.5 (from -r requirements.txt (line 20))
#   Downloading basicsr-1.3.5.tar.gz (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.4/161.4 kB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting beautifulsoup4==4.11.1 (from -r requirements.txt (line 21))
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 12.2 MB/s eta 0:00:00
# Collecting bleach==5.0.0 (from -r requirements.txt (line 22))
#   Downloading bleach-5.0.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 15.4 MB/s eta 0:00:00
# Collecting blinker==1.4 (from -r requirements.txt (line 23))
#   Downloading blinker-1.4.tar.gz (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting blobfile==1.3.1 (from -r requirements.txt (line 24))
#   Downloading blobfile-1.3.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 6.7 MB/s eta 0:00:00
# Collecting boto3==1.24.11 (from -r requirements.txt (line 25))
#   Downloading boto3-1.24.11-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.3 MB/s eta 0:00:00
# Collecting botocore==1.27.11 (from -r requirements.txt (line 26))
#   Downloading botocore-1.27.11-py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 77.1 MB/s eta 0:00:00:00:0100:01
# Collecting braceexpand==0.1.7 (from -r requirements.txt (line 27))
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting cachetools==5.2.0 (from -r requirements.txt (line 28))
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting certifi==2022.9.24 (from -r requirements.txt (line 29))
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 17.2 MB/s eta 0:00:00
# Collecting cffi==1.15.0 (from -r requirements.txt (line 30))
#   Downloading cffi-1.15.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.3/446.3 kB 39.7 MB/s eta 0:00:00
# Collecting charset-normalizer==2.0.12 (from -r requirements.txt (line 31))
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting click==8.1.3 (from -r requirements.txt (line 32))
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 10.3 MB/s eta 0:00:00
# Collecting colorama==0.4.5 (from -r requirements.txt (line 34))
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting commonmark==0.9.1 (from -r requirements.txt (line 35))
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: cycler==0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (0.11.0)
# Collecting dataclasses==0.6 (from -r requirements.txt (line 37))
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting datasets==2.3.2 (from -r requirements.txt (line 38))
#   Downloading datasets-2.3.2-py3-none-any.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.3/362.3 kB 32.6 MB/s eta 0:00:00
# Collecting debugpy==1.6.0 (from -r requirements.txt (line 39))
#   Downloading debugpy-1.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.8 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml==0.7.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (0.7.1)
# Collecting dill==0.3.5.1 (from -r requirements.txt (line 42))
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: docker-pycreds==0.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (0.4.0)
# Collecting editdistance==0.6.0 (from -r requirements.txt (line 44))
#   Downloading editdistance-0.6.0.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting etils==0.6.0 (from -r requirements.txt (line 47))
#   Downloading etils-0.6.0-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 8.1 MB/s eta 0:00:00
# Collecting facexlib==0.2.3 (from -r requirements.txt (line 49))
#   Downloading facexlib-0.2.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 5.9 MB/s eta 0:00:00
# Collecting fastjsonschema==2.15.3 (from -r requirements.txt (line 50))
#   Downloading fastjsonschema-2.15.3-py3-none-any.whl (22 kB)
# Collecting filelock==3.7.1 (from -r requirements.txt (line 51))
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting filterpy==1.4.5 (from -r requirements.txt (line 52))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flatbuffers==1.12 (from -r requirements.txt (line 53))
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting fonttools==4.33.3 (from -r requirements.txt (line 54))
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 kB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: fqdn==1.5.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (1.5.1)
# Collecting frozenlist==1.3.0 (from -r requirements.txt (line 56))
#   Downloading frozenlist-1.3.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 16.4 MB/s eta 0:00:00
# Collecting fsspec==2022.5.0 (from -r requirements.txt (line 57))
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 14.5 MB/s eta 0:00:00
# Collecting ftfy==6.1.1 (from -r requirements.txt (line 58))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.7 MB/s eta 0:00:00
# Collecting future==0.18.2 (from -r requirements.txt (line 59))
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 49.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fvcore==0.1.5.post20221221 (from -r requirements.txt (line 60))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gast==0.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (0.4.0)
# Collecting gfpgan==1.3.2 (from -r requirements.txt (line 62))
#   Downloading gfpgan-1.3.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 4.5 MB/s eta 0:00:00
# Collecting gin-config==0.5.0 (from -r requirements.txt (line 63))
#   Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 6.0 MB/s eta 0:00:00
# Collecting gitdb==4.0.9 (from -r requirements.txt (line 64))
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.6 MB/s eta 0:00:00
# Collecting GitPython==3.1.27 (from -r requirements.txt (line 65))
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 18.4 MB/s eta 0:00:00
# Collecting h5py==3.7.0 (from -r requirements.txt (line 66))
#   Downloading h5py-3.7.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 92.3 MB/s eta 0:00:00:00:01
# Collecting huggingface-hub==0.12.0 (from -r requirements.txt (line 67))
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 20.0 MB/s eta 0:00:00
# Collecting idna==3.3 (from -r requirements.txt (line 68))
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.3 MB/s eta 0:00:00
# Collecting imageio==2.9.0 (from -r requirements.txt (line 69))
#   Downloading imageio-2.9.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 86.3 MB/s eta 0:00:00:00:01
# Collecting imageio-ffmpeg==0.4.2 (from -r requirements.txt (line 70))
#   Downloading imageio_ffmpeg-0.4.2-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 51.1 MB/s eta 0:00:0000:0100:01
# Collecting imgaug==0.2.6 (from -r requirements.txt (line 71))
#   Downloading imgaug-0.2.6.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.4/631.4 kB 48.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting importlib-metadata==4.11.4 (from -r requirements.txt (line 72))
#   Downloading importlib_metadata-4.11.4-py3-none-any.whl (18 kB)
# Collecting importlib-resources==5.8.0 (from -r requirements.txt (line 73))
#   Downloading importlib_resources-5.8.0-py3-none-any.whl (28 kB)
# Collecting install==1.3.5 (from -r requirements.txt (line 74))
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting iopath==0.1.10 (from -r requirements.txt (line 75))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ipykernel==6.15.0 (from -r requirements.txt (line 76))
#   Downloading ipykernel-6.15.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 13.4 MB/s eta 0:00:00
# Collecting ipython==8.4.0 (from -r requirements.txt (line 77))
#   Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 53.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (0.2.0)
# Collecting ipywidgets==7.7.0 (from -r requirements.txt (line 79))
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: isoduration==20.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 80)) (20.11.0)
# Requirement already satisfied: Jinja2==3.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 82)) (3.1.2)
# Requirement already satisfied: jmespath==1.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 83)) (1.0.1)
# Collecting joblib==1.1.0 (from -r requirements.txt (line 84))
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 28.6 MB/s eta 0:00:00
# Collecting json5==0.9.11 (from -r requirements.txt (line 85))
#   Downloading json5-0.9.11-py2.py3-none-any.whl (19 kB)
# Collecting jsonpointer==2.3 (from -r requirements.txt (line 86))
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting jsonschema==4.17.3 (from -r requirements.txt (line 87))
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 9.1 MB/s eta 0:00:00
# Collecting jupyter-client==8.0.3 (from -r requirements.txt (line 88))
#   Downloading jupyter_client-8.0.3-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 9.9 MB/s eta 0:00:00
# Collecting jupyter-core==5.2.0 (from -r requirements.txt (line 89))
#   Downloading jupyter_core-5.2.0-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 9.2 MB/s eta 0:00:00
# Collecting jupyter-events==0.6.3 (from -r requirements.txt (line 90))
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting jupyter-server==2.3.0 (from -r requirements.txt (line 91))
#   Downloading jupyter_server-2.3.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.8/365.8 kB 30.0 MB/s eta 0:00:00
# Collecting jupyter-server-fileid==0.7.0 (from -r requirements.txt (line 92))
#   Downloading jupyter_server_fileid-0.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: jupyter-server-terminals==0.4.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (0.4.4)
# Collecting jupyter-server-ydoc==0.6.1 (from -r requirements.txt (line 94))
#   Downloading jupyter_server_ydoc-0.6.1-py3-none-any.whl (11 kB)
# Collecting jupyter-ydoc==0.2.2 (from -r requirements.txt (line 95))
#   Downloading jupyter_ydoc-0.2.2-py3-none-any.whl (5.6 kB)
# Collecting jupyterlab==3.6.1 (from -r requirements.txt (line 96))
#   Downloading jupyterlab-3.6.1-py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 89.4 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (0.2.2)
# Collecting jupyterlab-server==2.19.0 (from -r requirements.txt (line 98))
#   Downloading jupyterlab_server-2.19.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 1.6 MB/s eta 0:00:00
# Collecting jupyterlab-widgets==1.1.0 (from -r requirements.txt (line 99))
#   Downloading jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.1/245.1 kB 23.0 MB/s eta 0:00:00
# Collecting keras==2.9.0 (from -r requirements.txt (line 100))
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.0 MB/s eta 0:00:00
# Collecting Keras-Preprocessing==1.1.2 (from -r requirements.txt (line 101))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.9 MB/s eta 0:00:00
# Collecting kiwisolver==1.4.3 (from -r requirements.txt (line 102))
#   Downloading kiwisolver-1.4.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.4 MB/s eta 0:00:00
# Collecting kornia==0.6.9 (from -r requirements.txt (line 103))
#   Downloading kornia-0.6.9-py2.py3-none-any.whl (569 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.1/569.1 kB 44.3 MB/s eta 0:00:00
# Collecting libclang==14.0.1 (from -r requirements.txt (line 104))
#   Downloading libclang-14.0.1-py2.py3-none-manylinux1_x86_64.whl (14.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 83.6 MB/s eta 0:00:0000:0100:01
# Collecting lightning-utilities==0.6.0.post0 (from -r requirements.txt (line 105))
#   Downloading lightning_utilities-0.6.0.post0-py3-none-any.whl (18 kB)
# Collecting llvmlite==0.38.1 (from -r requirements.txt (line 106))
#   Downloading llvmlite-0.38.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 38.7 MB/s eta 0:00:0000:0100:01
# Collecting lmdb==1.3.0 (from -r requirements.txt (line 107))
#   Downloading lmdb-1.3.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.5/306.5 kB 26.7 MB/s eta 0:00:00
# Collecting Markdown==3.3.7 (from -r requirements.txt (line 108))
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 9.0 MB/s eta 0:00:00
# Collecting MarkupSafe==2.1.1 (from -r requirements.txt (line 109))
#   Downloading MarkupSafe-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting matplotlib==3.5.2 (from -r requirements.txt (line 110))
#   Downloading matplotlib-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 96.0 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib-inline==0.1.3 (from -r requirements.txt (line 111))
#   Downloading matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Collecting mesh-tensorflow==0.1.21 (from -r requirements.txt (line 112))
#   Downloading mesh_tensorflow-0.1.21-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: mistune==0.8.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (0.8.4)
# ERROR: Ignored the following versions that require a different python version: 0.36.0 Requires-Python >=3.6,<3.10; 0.37.0 Requires-Python >=3.7,<3.10; 0.7 Requires-Python >=3.6, <3.7; 0.8 Requires-Python >=3.6, <3.7
# ERROR: Could not find a version that satisfies the requirement mkl-fft==1.3.1 (from versions: 1.3.6)
# ERROR: No matching distribution found for mkl-fft==1.3.1
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.36.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Collecting openai-clip
#   Downloading openai-clip-1.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from openai-clip)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from openai-clip) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai-clip) (4.66.1)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->openai-clip)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/fd/84/fd2ba7aafacbad3c4201d395674fc6348826569da3c0937e75505ead3528/wcwidth-0.2.13-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 4.8 MB/s eta 0:00:00
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: openai-clip
#   Building wheel for openai-clip (setup.py) ... done
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368606 sha256=3d8895a5082caab6e26c4ace748fff05f028f115ad663b8db958bc5638fa65c4
#   Stored in directory: /root/.cache/pip/wheels/08/77/8e/8d2f862df6bf7fb4e2007062d2cbaeae49862ec7b56d041229
# Successfully built openai-clip
# Installing collected packages: wcwidth, ftfy, openai-clip
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
# Successfully installed ftfy-6.1.3 openai-clip-1.0.1 wcwidth-0.2.13
# Collecting einops
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/29/0b/2d1c0ebfd092e25935b86509a9a817159212d82aa43d7fb07eca4eeff2c2/einops-0.7.0-py3-none-any.whl.metadata
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Collecting pytorch_pretrained_biggan
#   Downloading pytorch_pretrained_biggan-0.1.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: torch>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from pytorch_pretrained_biggan) (2.0.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pytorch_pretrained_biggan) (1.24.3)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (from pytorch_pretrained_biggan) (1.26.100)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from pytorch_pretrained_biggan) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from pytorch_pretrained_biggan) (4.66.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.1->pytorch_pretrained_biggan) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.1->pytorch_pretrained_biggan) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.1->pytorch_pretrained_biggan) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.1->pytorch_pretrained_biggan) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.1->pytorch_pretrained_biggan) (3.1.2)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3->pytorch_pretrained_biggan)
#   Obtaining dependency information for botocore<1.30.0,>=1.29.100 from https://files.pythonhosted.org/packages/46/20/e7a9a8e6746872afcc4e3ad5ab503702c38813b3a532df27cce95c98b8cb/botocore-1.29.165-py3-none-any.whl.metadata
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3->pytorch_pretrained_biggan) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3->pytorch_pretrained_biggan) (0.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->pytorch_pretrained_biggan) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->pytorch_pretrained_biggan) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->pytorch_pretrained_biggan) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->pytorch_pretrained_biggan) (2023.11.17)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.100->boto3->pytorch_pretrained_biggan) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=0.4.1->pytorch_pretrained_biggan) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=0.4.1->pytorch_pretrained_biggan) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.100->boto3->pytorch_pretrained_biggan) (1.16.0)
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 85.1 MB/s eta 0:00:00:00:010:01
# Installing collected packages: botocore, pytorch_pretrained_biggan
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.33.13
#     Uninstalling botocore-1.33.13:
#       Successfully uninstalled botocore-1.33.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.9.0 requires botocore<1.33.14,>=1.33.2, but you have botocore 1.29.165 which is incompatible.
# Successfully installed botocore-1.29.165 pytorch_pretrained_biggan-0.1.1
# Requirement already satisfied: Ninja in /opt/conda/lib/python3.10/site-packages (1.11.1.1)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 10.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: torch>=1.4 in /opt/conda/lib/python3.10/site-packages (from timm==0.4.12) (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from timm==0.4.12) (0.15.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4->timm==0.4.12) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4->timm==0.4.12) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4->timm==0.4.12) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->timm==0.4.12) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->timm==0.4.12) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->timm==0.4.12) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->timm==0.4.12) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->timm==0.4.12) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->timm==0.4.12) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->timm==0.4.12) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 0.9.12
#     Uninstalling timm-0.9.12:
#       Successfully uninstalled timm-0.9.12
# Successfully installed timm-0.4.12
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (0.3.7)

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Obtaining dependency information for gdown from https://files.pythonhosted.org/packages/68/fb/c1bb2cfbf1ad068129e3d67f3420649d38183cca7118f4fa46cfe3c3adab/gdown-5.0.0-py3-none-any.whl.metadata
#   Downloading gdown-5.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.0.0

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1EX4J4Al5cGC8Z4ZPV5v576LBjLqw_Jt6" -O 'mae_pretrain_vit_base.pth'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1EX4J4Al5cGC8Z4ZPV5v576LBjLqw_Jt6
# From (redirected): https://drive.google.com/uc?export=download&id=1EX4J4Al5cGC8Z4ZPV5v576LBjLqw_Jt6&confirm=t&uuid=ab58a5cd-cdd1-4f43-b0bb-e6e6a4dfc014
# To: /kaggle/working/re-rosetta/mae_pretrain_vit_base.pth
# 100%|████████████████████████████████████████| 343M/343M [00:04<00:00, 82.5MB/s]

# %%
import PIL
gan_mode = 'styleganxl'
discr_mode = 'resnet50'

# %% [markdown]
# ## PAIRWISE MATCHING

# %%
from transformers import CLIPProcessor, CLIPModel
import torch
import torchvision
from torchvision.models import resnet50
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import clip
from PIL import Image
import requests
import torch.hub
import time
import pickle
import os
import numpy
import math
import match_utils
from match_utils import matching, stats, proggan, nethook, dataset, models, layers, loading, visualize_pairwisematch
device = torch.device('cuda')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !rm -rf imgs

# !mkdir -p imgs/dir0
# !mkdir -p imgs/dir1

# %%
from torchvision import datasets
val_dataset = datasets.ImageFolder(root = '/kaggle/input/imagenet-val-mini/imagenet-val-mini')
fname = val_dataset.classes[classid]

# %%
ip = f"/kaggle/input/imagenet-val-mini/imagenet-val-mini/{fname}"
ip
# Out:
# '/kaggle/input/imagenet-val-mini/imagenet-val-mini/n04266014'

# %%
num_steps = 200
lr_rampdown_length = 0.25
lr_rampup_length = 0.05
initial_learning_rate = 0.01
seed = 35
torch.manual_seed(seed)
device = torch.device(device)

# Load models and tables
discr, discr_layers = models.load_discr(discr_mode, device)

G, gan_layers = models.load_gan(gan_mode, device)
ganlayers, discrlayers = layers.get_layers(
    G, gan_layers, discr, discr_layers, gan_mode, discr_mode, device
)
G = nethook.InstrumentedModel(G)
G.retain_layers(gan_layers, detach=False)
discr = nethook.InstrumentedModel(discr)
discr.retain_layers(discr_layers)

all_images = {}
files = os.listdir(ip)
for file in files:
    file = file
    biggan_resolution = 128
    target_fname = f"{ip}/{file}"
    target_pil = PIL.Image.open(target_fname).convert("RGB")
    w, h = target_pil.size
    s = min(w, h)
    target_pil = target_pil.crop(
        ((w - s) // 2, (h - s) // 2, (w + s) // 2, (h + s) // 2)
    )
    target_pil = target_pil.resize(
        (biggan_resolution, biggan_resolution), PIL.Image.LANCZOS
    )
    target_uint8 = np.array(target_pil, dtype=np.uint8)
    plt.imshow(target_uint8)
    plt.axis('off')
    plt.savefig((f"imgs/dir0/{file}"[:-4] + "png").lower(), bbox_inches="tight", pad_inches=-0.1)
    plt.show()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 286MB/s]
# Downloading https://s3.eu-central-1.amazonaws.com/avg-projects/stylegan_xl/models/imagenet128.pkl ... done
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.

# %%
from scipy.stats import truncnorm


def truncate_noise(size, truncation):
    """
    Function for creating truncated noise vectors: Given the dimensions (n_samples, z_dim)
    and truncation value, creates a tensor of that shape filled with random
    numbers from the truncated normal distribution.
    Parameters:
        n_samples: the number of samples to generate, a scalar
        z_dim: the dimension of the noise vector, a scalar
        truncation: the truncation value, a non-negative scalar
    """

    truncated_noise = truncnorm.rvs(-1 * truncation, truncation, size=size)

    return torch.Tensor(truncated_noise)

# %%
# # target=torch.tensor(target_uint8.transpose([2, 0, 1]), device=device)


# for i in range(1, 10):
#     with open(f"imgs/dist{i}.txt", "w") as f:
#         f.write(f"{i}")

# %%
# k = 5
resnet_path = f"matches/{gan_mode}/{discr_mode}/{classid}"

table, gan_stats, discr_stats = loading.load_stats(resnet_path, device)
classs = classid
# Out:
# Loading...
# Done

# %%
code = '''
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
# from torch.autograd import Variable

from lpips.trainer import *
from lpips.lpips import *

def normalize_tensor(in_feat,eps=1e-10):
    norm_factor = torch.sqrt(torch.sum(in_feat**2,dim=1,keepdim=True))
    return in_feat/(norm_factor+eps)

def l2(p0, p1, range=255.):
    return .5*np.mean((p0 / range - p1 / range)**2)

def psnr(p0, p1, peak=255.):
    return 10*np.log10(peak**2/np.mean((1.*p0-1.*p1)**2))

def dssim(p0, p1, range=255.):
    from skimage.measure import compare_ssim
    return (1 - compare_ssim(p0, p1, data_range=range, multichannel=True)) / 2.

def tensor2np(tensor_obj):
    # change dimension of a tensor object into a numpy array
    return tensor_obj[0].cpu().float().numpy().transpose((1,2,0))

def np2tensor(np_obj):
     # change dimenion of np array into tensor array
    return torch.Tensor(np_obj[:, :, :, np.newaxis].transpose((3, 2, 0, 1)))

def tensor2tensorlab(image_tensor,to_norm=True,mc_only=False):
    # image tensor to lab tensor
    from skimage import color

    img = tensor2im(image_tensor)
    img_lab = color.rgb2lab(img)
    if(mc_only):
        img_lab[:,:,0] = img_lab[:,:,0]-50
    if(to_norm and not mc_only):
        img_lab[:,:,0] = img_lab[:,:,0]-50
        img_lab = img_lab/100.

    return np2tensor(img_lab)

def tensorlab2tensor(lab_tensor,return_inbnd=False):
    from skimage import color
    import warnings
    warnings.filterwarnings("ignore")

    lab = tensor2np(lab_tensor)*100.
    lab[:,:,0] = lab[:,:,0]+50

    rgb_back = 255.*np.clip(color.lab2rgb(lab.astype('float')),0,1)
    if(return_inbnd):
        # convert back to lab, see if we match
        lab_back = color.rgb2lab(rgb_back.astype('uint8'))
        mask = 1.*np.isclose(lab_back,lab,atol=2.)
        mask = np2tensor(np.prod(mask,axis=2)[:,:,np.newaxis])
        return (im2tensor(rgb_back),mask)
    else:
        return im2tensor(rgb_back)

def load_image(path):
    if(path[-3:] == 'dng'):
        import rawpy
        with rawpy.imread(path) as raw:
            img = raw.postprocess()
    elif(path[-3:]=='bmp' or path[-3:]=='jpg' or path[-3:]=='png' or path[-4:]=='jpeg'):
        import cv2
        return cv2.imread(path)[:,:,::-1]
    else:
        import matplotlib.pyplot as plt        
        img = (255*plt.imread(path)[:,:,:3]).astype('uint8')

    return img

def tensor2im(image_tensor, imtype=np.uint8, cent=1., factor=255./2.):
    image_numpy = image_tensor[0].cpu().float().numpy()
    image_numpy = (np.transpose(image_numpy, (1, 2, 0)) + cent) * factor
    return image_numpy.astype(imtype)

def im2tensor(image, imtype=np.uint8, cent=1., factor=255./2.):
    return torch.Tensor((image / factor - cent)
                        [:, :, :, np.newaxis].transpose((3, 2, 0, 1)))

def tensor2vec(vector_tensor):
    return vector_tensor.data.cpu().numpy()[:, :, 0, 0]


def voc_ap(rec, prec, use_07_metric=False):
    """ ap = voc_ap(rec, prec, [use_07_metric])
    Compute VOC AP given precision and recall.
    If use_07_metric is true, uses the
    VOC 07 11 point method (default:False).
    """
    if use_07_metric:
        # 11 point metric
        ap = 0.
        for t in np.arange(0., 1.1, 0.1):
            if np.sum(rec >= t) == 0:
                p = 0
            else:
                p = np.max(prec[rec >= t])
            ap = ap + p / 11.
    else:
        # correct AP calculation
        # first append sentinel values at the end
        mrec = np.concatenate(([0.], rec, [1.]))
        mpre = np.concatenate(([0.], prec, [0.]))

        # compute the precision envelope
        for i in range(mpre.size - 1, 0, -1):
            mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

        # to calculate area under PR curve, look for points
        # where X axis (recall) changes value
        i = np.where(mrec[1:] != mrec[:-1])[0]

        # and sum (\Delta recall) * prec
        ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
    return ap'''

# %%
# !pip install lpips
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from lpips) (2.0.0)
# Requirement already satisfied: torchvision>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from lpips) (0.15.1)
# Requirement already satisfied: numpy>=1.14.3 in /opt/conda/lib/python3.10/site-packages (from lpips) (1.24.3)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from lpips) (1.11.4)
# Requirement already satisfied: tqdm>=4.28.1 in /opt/conda/lib/python3.10/site-packages (from lpips) (4.66.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->lpips) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->lpips) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->lpips) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->lpips) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->lpips) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.2.1->lpips) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.2.1->lpips) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=0.4.0->lpips) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.2.1->lpips) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.2.1->lpips) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.2.1->lpips) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.2.1->lpips) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=0.4.0->lpips) (1.3.0)
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
with open("/opt/conda/lib/python3.10/site-packages/lpips/__init__.py","w") as f:
    f.write(code)

# %%
import torch.nn.functional as F

# %%
import lpips

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
for k in range(1, 2):
    gan_matches = torch.argmax(table, 1)
    _, discr_matches = torch.topk(table, k=k, dim=0)

    ##get best buddies
    perfect_matches = []
    discr_perfect_matches = []
    num_perfect_matches = 0
    for i in range(table.shape[0]):
        gan_match = gan_matches[i].item()
        discr_match = discr_matches[:, gan_match]
        if discr_match.ndim == 1:
            if i in discr_match:
                num_perfect_matches += 1
                perfect_matches.append(i)
                discr_perfect_matches.append(gan_match)
        else:
            if i == discr_match:
                num_perfect_matches += 1
                perfect_matches.append(i)
                discr_perfect_matches.append(gan_match)
    #     getting everything in (layer, unit) form
    for i, unit in enumerate(perfect_matches):
        perfect_matches[i] = layers.find_act(perfect_matches[i], ganlayers)
    for i, unit in enumerate(discr_perfect_matches):
        discr_perfect_matches[i] = layers.find_act(
            discr_perfect_matches[i], discrlayers
        )
    all_images = {}
    biggan_resolution = 128
    files = os.listdir(ip)
    for file in files:
        target_fname = f"{ip}/{file}"
        discr_im = Image.open(target_fname).convert("RGB")
        discr_im_np = discr_im
        discr_im = torchvision.transforms.ToTensor()(discr_im).unsqueeze(0).to(device)

        discr_im = torch.nn.functional.interpolate(
            discr_im, size=(224, 224), mode="bicubic"
        )
        discr_im = torchvision.transforms.Normalize(
            (0.485, 0.456, 0.406), (0.229, 0.224, 0.225)
        )(discr_im)
        #         plt.imshow(discr_im.squeeze().permute(1,2,0).cpu())
        #         plt.show()

        logits = discr(discr_im)
        assert(classid, torch.argmax(logits))
        discr_activs = matching.store_activs(discr, discr_layers)

        # normalize
        eps = 0.00001
        for i, _ in enumerate(discr_activs):
            discr_activs[i] = (discr_activs[i] - discr_stats[i][0]) / (
                discr_stats[i][1] + eps
            )

        discr_perfect_activs = []
        for idx in discr_perfect_matches:
            discr_perfect_activs.append(
                discr_activs[idx[0]][:, idx[1], :, :].unsqueeze(0)
            )

        #     target_images = target.unsqueeze(0).to(device).to(torch.float32)
        z = truncate_noise((1, 64), 1).to(device)
        c = torch.zeros((1, 1000)).to(device)
        c[0, classs] = 1
        im = G(z, c, 1)
        im = im[0].permute((1, 2, 0))
        im = (im + 1) / 2
        print(f"{classid} : {file} , initially generated image")
        plt.imshow(im.detach().cpu())
        plt.title('initially generated image')
        plt.show()
        z1 = torch.tensor(
            truncate_noise((1, 64), 1),
            dtype=torch.float32,
            device=device,
            requires_grad=True,
        ).to(
            device
        )  # pylint: disable=not-callable
        optimizer = torch.optim.Adam([z1], betas=(0.9, 0.999), lr=initial_learning_rate)
        # @title Inversion
        # all_images = []
        for step in range(num_steps):
            # Learning rate schedule.
            t = step / num_steps
            lr_ramp = min(1.0, (1.0 - t) / lr_rampdown_length)
            lr_ramp = 0.5 - 0.5 * np.cos(lr_ramp * np.pi)
            lr_ramp = lr_ramp * min(1.0, t / lr_rampup_length)
            lr = initial_learning_rate * lr_ramp
            for param_group in optimizer.param_groups:
                param_group["lr"] = lr

            # Synth images from opt_w.
            synth_images = G(z1, c, 1)

            # track images
            synth_images = (synth_images + 1) * (255 / 2)
            synth_images_np = (
                synth_images.clone()
                .detach()
                .permute(0, 2, 3, 1)
                .clamp(0, 255)
                .to(torch.uint8)[0]
                .cpu()
                .numpy()
            )
            #     all_images.append(synth_images_np)

            # Downsample image to 256x256 if it's larger than that. VGG was built for 224x224 images.
            if synth_images.shape[2] > 256:
                synth_images = F.interpolate(synth_images, size=(256, 256), mode="area")

            gan_activs = matching.store_activs(G, gan_layers)
            # normalize all activations
            eps = 0.00001
            for i, _ in enumerate(gan_activs):
                gan_activs[i] = (gan_activs[i] - gan_stats[i][0]) / (
                    gan_stats[i][1] + eps
                )

            gan_perfect_activs = []
            for idx in perfect_matches:
                gan_perfect_activs.append(gan_activs[idx[0]][:, idx[1], :, :])

            # pearson correlation
            a_loss = 0
            counter = len(gan_perfect_activs)
            for i, _ in enumerate(gan_perfect_activs):
                map_size = max(
                    (gan_perfect_activs[i].shape[1], discr_perfect_activs[i].shape[1])
                )
                gan_activ_new = torch.nn.Upsample(
                    size=(map_size, map_size), mode="bilinear"
                )(gan_perfect_activs[i].unsqueeze(0))
                discr_activ_new = torch.nn.Upsample(
                    size=(map_size, map_size), mode="bilinear"
                )(discr_perfect_activs[i])
                prod = torch.einsum("aixy,ajxy->ij", gan_activ_new, discr_activ_new)
                div1 = torch.sum(gan_activ_new**2)
                div2 = torch.sum(discr_activ_new**2)
                corr = prod / torch.sqrt(div1 * div2)
                a_loss += corr

            a_loss *= -1
            a_loss = a_loss / counter
            l_reg = torch.mean((z1 - z) ** 2)
            
            # perceptual loss
#             assert(synth_images.shape == discr_im.shape)
#             print('----', synth_images.shape, discr_im.shape, '----')
#             mse_loss = torch.nn.MSELoss(synth_images, F.interpolate(discr_im, size=(128, 128), mode='area'))
            
            # Features for synth images.
            loss = a_loss + 0 * l_reg
            # Step
            optimizer.zero_grad(set_to_none=True)

            loss.backward()
            optimizer.step()
            msg  = f'[ step {step+1:>4d}/{num_steps}] '
            msg += f'[ a_loss: {float(a_loss):5.2f} loss_reg: {0.1 * float(l_reg):5.2f}] '
            if (step+1)%50 == 0:
                print(msg) 
            if step == num_steps - 1:
                plt.imshow(synth_images_np)
                plt.axis("off")
                file = file[:-4] + "png"
                print(f"inverted image - {classid}:{file}")
                plt.savefig(f"imgs/dir1/{file}".lower(), bbox_inches="tight", pad_inches=-0.1)
                #         if step % 50 == 0:
                #             plt.imshow(synth_images_np)
                #             plt.show()
#                 command = f"python calc_metrics.py  --dir0 imgs/dir0 --dir1 imgs/dir1 -o imgs/dist{k}.txt --use_gpu --version 0.1"
#                 os.system(command)
# Out:
# 812 : ILSVRC2012_val_00005787.JPEG , initially generated image
# [ step   50/200] [ a_loss: -0.29 loss_reg:  0.07]
# [ step  100/200] [ a_loss: -0.32 loss_reg:  0.07]
# [ step  150/200] [ a_loss: -0.34 loss_reg:  0.07]
# [ step  200/200] [ a_loss: -0.35 loss_reg:  0.07]
# inverted image - 812:ILSVRC2012_val_00005787.png
# 812 : ILSVRC2012_val_00033013.JPEG , initially generated image
# [ step   50/200] [ a_loss: -0.13 loss_reg:  0.07]
# [ step  100/200] [ a_loss: -0.15 loss_reg:  0.07]
# [ step  150/200] [ a_loss: -0.15 loss_reg:  0.06]
# [ step  200/200] [ a_loss: -0.16 loss_reg:  0.06]
# inverted image - 812:ILSVRC2012_val_00033013.png
# 812 : ILSVRC2012_val_00034371.JPEG , initially generated image
# [ step   50/200] [ a_loss: -0.16 loss_reg:  0.07]
# [ step  100/200] [ a_loss: -0.20 loss_reg:  0.07]
# [ step  150/200] [ a_loss: -0.21 loss_reg:  0.07]
# [ step  200/200] [ a_loss: -0.22 loss_reg:  0.07]
# inverted image - 812:ILSVRC2012_val_00034371.png
# 812 : ILSVRC2012_val_00049718.JPEG , initially generated image
# [ step   50/200] [ a_loss: -0.32 loss_reg:  0.05]
# [ step  100/200] [ a_loss: -0.41 loss_reg:  0.06]
# [ step  150/200] [ a_loss: -0.43 loss_reg:  0.06]
# [ step  200/200] [ a_loss: -0.44 loss_reg:  0.06]
# inverted image - 812:ILSVRC2012_val_00049718.png

# %%
command = f"python calc_metrics.py  --dir0 imgs/dir0 --dir1 imgs/dir1 -o imgs/dist.txt --use_gpu --version 0.1"
os.system(command)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/working/re-rosetta/calc_metrics.py:92: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /opt/conda/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth
# 100%|██████████| 4/4 [00:00<00:00,  7.97it/s]
# LPIPS 0.62637436
# SSIM 0.54005855524559
# PSNR 12.830168962816883
# LEN 4
# 0

# %%
# !zip -r inversion_results.zip imgs
# Out:
# updating: imgs/ (stored 0%)
# updating: imgs/dir1/ (stored 0%)
# updating: imgs/dir1/ilsvrc2012_val_00049718.png (deflated 0%)
# updating: imgs/dir1/ilsvrc2012_val_00033013.png (deflated 0%)
# updating: imgs/dir1/ilsvrc2012_val_00034371.png (deflated 0%)
# updating: imgs/dir1/ilsvrc2012_val_00005787.png (deflated 0%)
# updating: imgs/dir0/ (stored 0%)
# updating: imgs/dir0/ilsvrc2012_val_00049718.png (deflated 0%)
# updating: imgs/dir0/ilsvrc2012_val_00033013.png (deflated 0%)
# updating: imgs/dir0/ilsvrc2012_val_00034371.png (deflated 0%)
# updating: imgs/dir0/ilsvrc2012_val_00005787.png (deflated 0%)
# updating: imgs/dist.txt (deflated 47%)
